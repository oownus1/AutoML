# %% [markdown]
# ## 기본 모듈 import

# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.options.display.max_columns = None

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc("font", family='NanumGothic')
plt.rc("axes", unicode_minus=False)

pd.Series([1, 3, 5, -7, 9]).plot(title="한글")
# Out:
# <AxesSubplot:title={'center':'한글'}>

# %% [markdown]
# ## 데이터셋 로드

# %%
dataset =  pd.read_csv('data/20220217_KT.txt', encoding='cp949', sep='|')

display(dataset.shape)
dataset.head()
# Out:
# (2819174, 20)
#       계약코드      체납액      미납액  수납액  최초연체개월수  최종연체개월수    나이  \
# 0  9170101  5017230  5017230    0       19       19  50.0
# 1  9170101     6800     6800    0       11       11  50.0
# 2  9170101  3478250  3478250    0       12       12  21.0
# 3  9170101   411110   411110    0       22       22  21.0
# 4  9170101   334230   334230    0       39       60  20.0
#
#                      체납액분류 회수분류     최초연체개월분류  위임월 주민종류      연령대     성별    지점  \
# 0  (I) 500만원 이상~ 1000만원 미만  미수납  (F)19~24 연체  01월   개인  (E) 50대  (A)남성   경기도
# 1               (A) 1만원 미만  미수납   (D)7~12 연체  01월   개인  (E) 50대  (A)남성   부산시
# 2   (H) 100만원 이상~ 500만원 미만  미수납   (D)7~12 연체  01월   개인  (B) 20대  (A)남성  전라남도
# 3     (F) 30만원 이상~ 50만원 미만  미수납  (F)19~24 연체  01월   개인  (B) 20대  (B)여성  전라남도
# 4     (F) 30만원 이상~ 50만원 미만  미수납  (H)37~48 연체  01월   개인  (B) 20대  (A)남성   경기도
#
#   위임연락처여부 당사획득연락처여부 위임주소여부 당사획득주소여부 초본주소여부
# 0     미존재       미존재     01       11     11
# 1     미존재       미존재    미존재      미존재    미존재
# 2       3       미존재     01      미존재    미존재
# 3     미존재       미존재    미존재       11    미존재
# 4       3       미존재    미존재      미존재    미존재

# %% [markdown]
# ## 학습데이터 정의

# %%
data = dataset.copy()

# %%
data['회수분류'].value_counts()
# Out:
# 미수납    2682148
# 수납      137026
# Name: 회수분류, dtype: int64

# %%
data['collection'] = data['회수분류'].map({'미수납':0, '수납':1})
# data['collection'] = data['회수분류'].apply(lambda x : 1 if x == '수납' else 0)

data['collection'].value_counts()
# Out:
# 0    2682148
# 1     137026
# Name: collection, dtype: int64

# %%
data.isnull().sum()
# Out:
# 계약코드            0
# 체납액             0
# 미납액             0
# 수납액             0
# 최초연체개월수         0
# 최종연체개월수         0
# 나이            541
# 체납액분류           0
# 회수분류            0
# 최초연체개월분류        0
# 위임월             0
# 주민종류            0
# 연령대             0
# 성별              0
# 지점              0
# 위임연락처여부         0
# 당사획득연락처여부       0
# 위임주소여부          0
# 당사획득주소여부        0
# 초본주소여부          0
# collection      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2819174 entries, 0 to 2819173
# Data columns (total 21 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   계약코드        int64
#  1   체납액         int64
#  2   미납액         int64
#  3   수납액         int64
#  4   최초연체개월수     int64
#  5   최종연체개월수     int64
#  6   나이          float64
#  7   체납액분류       object
#  8   회수분류        object
#  9   최초연체개월분류    object
#  10  위임월         object
#  11  주민종류        object
#  12  연령대         object
#  13  성별          object
#  14  지점          object
#  15  위임연락처여부     object
#  16  당사획득연락처여부   object
#  17  위임주소여부      object
#  18  당사획득주소여부    object
#  19  초본주소여부      object
#  20  collection  int64
# dtypes: float64(1), int64(7), object(13)
# memory usage: 451.7+ MB

# %%
data.columns
# Out:
# Index(['계약코드', '체납액', '미납액', '수납액', '최초연체개월수', '최종연체개월수', '나이', '체납액분류',
#        '회수분류', '최초연체개월분류', '위임월', '주민종류', '연령대', '성별', '지점', '위임연락처여부',
#        '당사획득연락처여부', '위임주소여부', '당사획득주소여부', '초본주소여부', 'collection'],
#       dtype='object')

# %%
features = [
#     '계약코드',
    '체납액',
#     '미납액',
#     '수납액',
    '최초연체개월수', 
    '최종연체개월수', 
    '나이', 
#     '체납액분류',
#     '회수분류',  ## target
#     '최초연체개월분류', 
    '위임월', 
    '주민종류', 
#     '연령대', 
    '성별', 
    '지점', 
    '위임연락처여부',
    '당사획득연락처여부', 
    '위임주소여부', 
    '당사획득주소여부', 
    '초본주소여부'] 
target = 'collection'

# %%
x = data[features]
y = data[target]
     
xy = pd.concat([x, y], axis=1)

display(xy.shape)
xy.head()
# Out:
# (2819174, 14)
#        체납액  최초연체개월수  최종연체개월수    나이  위임월 주민종류     성별    지점 위임연락처여부 당사획득연락처여부  \
# 0  5017230       19       19  50.0  01월   개인  (A)남성   경기도     미존재       미존재
# 1     6800       11       11  50.0  01월   개인  (A)남성   부산시     미존재       미존재
# 2  3478250       12       12  21.0  01월   개인  (A)남성  전라남도       3       미존재
# 3   411110       22       22  21.0  01월   개인  (B)여성  전라남도     미존재       미존재
# 4   334230       39       60  20.0  01월   개인  (A)남성   경기도       3       미존재
#
#   위임주소여부 당사획득주소여부 초본주소여부  collection
# 0     01       11     11           0
# 1    미존재      미존재    미존재           0
# 2     01      미존재    미존재           0
# 3    미존재       11    미존재           0
# 4    미존재      미존재    미존재           0

# %%
xy[xy['collection'] == 1].head()
# Out:
#         체납액  최초연체개월수  최종연체개월수    나이  위임월 주민종류     성별    지점 위임연락처여부 당사획득연락처여부  \
# 11    11850       27       27  19.0  01월   개인  (A)남성    서울       2       미존재
# 17    89490        4        4  18.0  01월   개인  (B)여성  충청남도       3         3
# 20     2010        3        3  17.0  01월   개인  (A)남성    서울       3       미존재
# 28   188710        4        7  14.0  01월   개인  (A)남성  충청남도       3       미존재
# 32  4040950       44       45  50.0  01월   개인  (B)여성   부산시       3       미존재
#
#    위임주소여부 당사획득주소여부 초본주소여부  collection
# 11     01      미존재    미존재           1
# 17     01      미존재    미존재           1
# 20     01      미존재    미존재           1
# 28    미존재      미존재    미존재           1
# 32    미존재       01    미존재           1

# %% [markdown]
# ## 학습 및 예측

# %%
from pycaret.classification import *  # 분류
# from pycaret.regression import *      # 회귀
# from pycaret.clustering import *      # 군집
# from pycaret.anomaly import *         # 이상 탐지
# from pycaret.arules import *          # 연관 규칙

# %%
clf = setup(data=xy, 
            target=target, 
            session_id=123,
            silent=True)
# Out:
# <style type="text/css">
# #T_b28aa_row5_col1, #T_b28aa_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_51722_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_51722_row10_col0" class="data row10 col0" >0.9432</td>
#       <td id="T_51722_row10_col1" class="data row10 col1" >0.6977</td>
#       <td id="T_51722_row10_col2" class="data row10 col2" >0.4258</td>
#       <td id="T_51722_row10_col3" class="data row10 col3" >0.4168</td>
#       <td id="T_51722_row10_col4" class="data row10 col4" >0.4212</td>
#       <td id="T_51722_row10_col5" class="data row10 col5" >0.3914</td>
#       <td id="T_51722_row10_col6" class="data row10 col6" >0.3914</td>
#     </tr>
#     <tr>
#       <th id="T_51722_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_51722_row11_col0" class="data row11 col0" >0.0004</td>
#       <td id="T_51722_row11_col1" class="data row11 col1" >0.0027</td>
#       <td id="T_51722_row11_col2" class="data row11 col2" >0.0055</td>
#       <td id="T_51722_row11_col3" class="data row11 col3" >0.0039</td>
#       <td id="T_51722_row11_col4

# %%
# ensembled_models = ensemble_model(dt)

# %%
# predict_model(data=dataset, estimator=ensembled_models)
prediction = predict_model(data=xy, estimator=dt)
prediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_dca69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dca69_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dca69_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_dca69_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_dca69_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_dca69_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_dca69_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_dca69_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_dca69_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dca69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dca69_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_dca69_row0_col1" class="data row0 col1" >0.9832</td>
#       <td id="T_dca69_row0_col2" class="data row0 col2" >0.9101</td>
#       <td id="T_dca69_row0_col3" class="data row0 col3" >0.8290</td>
#       <td id="T_dca69_row0_col4" class="data row0 col4" >0.8261</td>
#       <td id="T_dca69_row0_col5" class="data row0 col5" >0.8275</td>
#       <td id="T_dca69_row0_col6" class="data row0 col6" >0.8187</td>
#       <td id="T_dca69_row0_col7" class="data row0 col7" >0.8187</td>
#     </tr>
#   </tbody>
# </table>
#              체납액  최초연체개월수  최종연체개월수    나이  위임월   주민종류     성별    지점 위임연락처여부  \
# 0        5017230       19       19  50.0  01월     개인  (A)남성   경기도     미존재
# 1           6800       11       11  50.0  01월     개인  (A)남성   부산시     미존재
# 2        3478250       12       12  21.0  01월     개인  (A)남성  전라남도       3
# 3         411110       22       22  21.0  01월     개인  (B)여성  전라남도     미존재
# 4         334230       39       60  20.0  01월     개인  (A)남성   경기도       3
# ...          ...      ...      ...   ...  ...    ...    ...   ...     ...
# 2819169   892130       52       61   0.0  06월    외국인  (Z)기타    서울     미존재
# 2819170   158680       55       55   0.0  06월  개인사업자  (Z)기타    서울     미존재
# 2819171   147270       67       67  44.0  06월     개인  (A)남성  전라남도     미존재
# 2819172   105150       28       34  45.0  06월     개인  (A)남성    서울     미존재
# 2819173     1220       10       10   0.0  06월  개인사업자  (B)여성    서울     미존재
#
#         당사획득연락처여부 위임주소여부 당사획득주소여부 초본주소여부  collection  Label  Score
# 0             미존재     01       11     11           0      0    1.0
# 1             미존재    미존재      미존재    미존재           0      0    1.0
# 2             미존재     01      미존재    미존재           0      0    1.0
# 3             미존재    미존재       11    미존재           0      0    1.0
# 4             미존재    미존재      미존재    미존재           0      0    1.0
# ...           ...    ...      ...    ...         ...    ...    ...
# 2819169       미존재    미존재      미존재    미존재           0      0    1.0
# 2819170       미존재    미존재      미존재    미존재           0      0    1.0
# 2819171       미존재    미존재       11     01           0      0    1.0
# 2819172       미존재    미존재      미존재    미존재           0      0    1.0
# 2819173       미존재    미존재      미존재    미존재           0      0    1.0
#
# [2819174 rows x 16 columns]

# %%
prediction[prediction['Label'] == 1].head()
# Out:
#         체납액  최초연체개월수  최종연체개월수    나이  위임월 주민종류     성별    지점 위임연락처여부 당사획득연락처여부  \
# 10  2219670        9       11  20.0  01월   개인  (A)남성    서울       J       미존재
# 11    11850       27       27  19.0  01월   개인  (A)남성    서울       2       미존재
# 17    89490        4        4  18.0  01월   개인  (B)여성  충청남도       3         3
# 18   104510       67       67  16.0  01월   개인  (A)남성   강원도     미존재       미존재
# 28   188710        4        7  14.0  01월   개인  (A)남성  충청남도       3       미존재
#
#    위임주소여부 당사획득주소여부 초본주소여부  collection  Label  Score
# 10     01       11     01           0      1    1.0
# 11     01      미존재    미존재           1      1    1.0
# 17     01      미존재    미존재           1      1    1.0
# 18     01       11    미존재           0      1    1.0
# 28    미존재      미존재    미존재           1      1    1.0

# %% [markdown]
# ## 모델 분석

# %%
plot_model(dt, plot='feature')

# %%
# plot_model(dt, plot='confusion_matrix')

# %%
interpret_model(dt)

# %%
# interpret_model(dt, plot='reason')

# %% [markdown]
# ## 모든 모델 학습

# %%
best_model = compare_models(sort='Accuracy', n_select=3, fold=5)
print(best_model)

# %%
blended_models = blend_models(best_models, fold=5)

# %% [markdown]
# ## 한글 테스트

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

# 운영체제에 맞는 font_family 찾기 
font_family = get_font_family()
display(font_family)

# 그래프 스타일 설정
# plt.style.use("fivethirtyeight")
# plt.style.use("bmh")

# dark mode 사용자를 위한 스타일 추천
# plt.style.use("dark_background")
plt.style.use("seaborn-whitegrid")

# 폰트설정
plt.rc("font", family=font_family)
# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)

# 그래프에 retina display 적용
from IPython.display import set_matplotlib_formats

set_matplotlib_formats("retina")

# 한글폰트 확인
pd.Series([1, 3, 5, -7, 9]).plot(title="한글")
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# /bin/bash: fc-cache: command not found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 27>()
#      24     return font_family
#      26 # 운영체제에 맞는 font_family 찾기
# ---> 27 font_family = get_font_family()
#      28 display(font_family)
#      30 # 그래프 스타일 설정
#      31 # plt.style.use("fivethirtyeight")
#      32 # plt.style.use("bmh")
#      33
#      34 # dark mode 사용자를 위한 스타일 추천
#      35 # plt.style.use("dark_background")
#
# Input In [21], in get_font_family()
#      15 get_ipython().system('fc-cache -fv')
#      17 import matplotlib as mpl
# ---> 18 mpl.font_manager._rebuild()
#      19 findfont = mpl.font_manager.fontManager.findfont
#      20 mpl.font_manager.findfont = findfont
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'
